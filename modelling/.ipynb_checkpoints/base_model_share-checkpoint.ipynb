# %%
# %reload_ext autoreload
#%autoreload
import pandas as pd
import numpy as np
import sys
import re
from functools import reduce
from typing import Dict
from pandas.tseries.offsets import MonthEnd
from datetime import datetime
import re
import plotly.express as px
from itertools import chain
from pandas.tseries.offsets import MonthEnd
from dateutil.relativedelta import relativedelta
pd.set_option('display.max_columns', 200)

# %%
sys.path.append('../scripts')
from data_utils import gen_features_share
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11748/4182902008.py in <module>
#       1 sys.path.append('../scripts')
# ----> 2 from data_utils import gen_features_share
#
# ModuleNotFoundError: No module named 'data_utils'

# %%
sys.path.append('..')
from utils import gen_features_share

# %%
import scripts

# %%
import data

# %%
df = pd.read_parquet('../data/prepared_df.parquet')

# %%
data_path + 'prepared_df.parquet'
# Out:
# ' ../data/prepared_df.parquet'

# %%
data_path = '../data/'
df = pd.read_parquet(data_path + 'prepared_df.parquet')
kr = pd.read_excel(data_path + 'cb_data.xlsx', dtype = {'Дата': 'str'})
# Out:
# C:\Users\DNS\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.head()
# Out:
#      objectid report_date  escrow_inflow  S_inflow  S_object object_open_date  \
# 183   27214.0  2024-03-31            NaN       NaN  47367.00       2018-06-28
# 498   34508.0  2024-03-31            NaN       NaN  65329.75       2019-09-23
# 499   34508.0  2024-04-30            NaN       NaN  65329.75       2019-09-23
# 500   34508.0  2024-05-31            NaN       NaN  65329.75       2019-09-23
# 501   34508.0  2024-06-30            NaN       NaN  65329.75       2019-09-23
#
#     object_close_date escrow_plan_close escrow_fact_close  \
# 183        2024-03-31               NaT               NaT
# 498        2024-06-30               NaT               NaT
# 499        2024-06-30               NaT               NaT
# 500        2024-06-30               NaT               NaT
# 501        2024-06-30               NaT               NaT
#
#     escrow_object_open_date escrow_status region_num  mean_price_per_metr  \
# ...

# %%
kr.head()
# Out:
#       Дата  Ключевая ставка, % годовых  Инфляция, % г/г  Цель по инфляции
# 0  02.2024                        16.0             7.69               4.0
# 1  01.2024                        16.0             7.44               4.0
# 2  12.2023                        16.0             7.42               4.0
# 3  11.2023                        15.0             7.48               4.0
# 4  10.2023                        15.0             6.69               4.0

# %% [markdown]
# ## Training share model

# %%
from sklearn.model_selection import TimeSeriesSplit
from catboost import cv
from catboost import Pool
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
def CustomSplit(df, n_splits = 5, test_size = 3, date_col = 'report_date', freq = 'M'):
    df = df.reset_index(drop = True)
    dates = pd.date_range(df[date_col].min(), df[date_col].max(), freq = freq)
    tscv = TimeSeriesSplit(n_splits = n_splits, test_size = test_size)
    return iter([[df[df[date_col].isin(dates[train_idx])].index, df[df[date_col].isin(dates[test_idx])].index] for train_idx, test_idx in tscv.split(dates)])


data = gen_features(df, kr) 


df_train, df_test = data[data['report_date'] <= pd.to_datetime('2023-12-31')], data[data['report_date'] > pd.to_datetime('2023-12-31')]

drop_cols, target_cols = ['report_date', 'key_rate_diff',  'objectid', 'S_volume', 
                          'S_share_shift4_diff', 'S_share_shift5_diff', 'S_share_shift3_diff3',
                         'key_rate-key_rate_mean_6'], ['S_share']
X_train, y_train = df_train.drop(columns = [*drop_cols, *target_cols]), df_train[target_cols]


class SigmoidMaeObjective(object):
    def calc_ders_range(self, approxes, targets, weights):
        assert len(approxes) == len(targets)
        if weights is not None:
            assert len(weights) == len(approxes)
        
        result = []
        for index in range(len(targets)):
            der1 = targets[index] - approxes[index]
            der2 = -1
            #der1 = np.sign(targets[index] - 1 / (1 + np.exp(-approxes[index]))) * np.exp(-approxes[index]) / ((1 + np.exp(-approxes[index]))**2)
            #der2 = np.sign(targets[index] - 1 / (1 + np.exp(-approxes[index]))) * \
            #        (2*np.exp(-2*approxes[index]) / ((1 + np.exp(-approxes[index]))**3) - np.exp(-approxes[index]) / ((1 + np.exp(-approxes[index]))**2))

            if weights is not None:
                der1 *= weights[index]
                der2 *= weights[index]

            result.append((der1, der2))
        return result


class SigmoidMaeMetric(object):
    def get_final_error(self, error, weight):
        return error / (weight + 1e-38)

    def is_max_optimal(self):
        return False

    def evaluate(self, approxes, target, weight):
        assert len(approxes) == 1
        assert len(target) == len(approxes[0])

        approx = approxes[0]

        error_sum = 0.0
        weight_sum = 0.0

        for i in range(len(approx)):
            w = 1.0 if weight is None else weight[i]
            weight_sum += w
            error_sum += w * abs(target[i] - 1 / (1 + np.exp(-approx[i])))

        return error_sum, weight_sum



params = {
    'eval_metric': 'MAE',#SigmoidMaeMetric(),
    'loss_function': 'MAE'#SigmoidMaeObjective()
}

cv_dataset = Pool(data=X_train,
                  label=y_train)


iter_scores = cv(cv_dataset,
                 params = params,
                 plot=True,
                 verbose = False,
                 folds=CustomSplit(df_train),
                 return_models = True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/5]
#
# bestTest = 0.03827411451
# bestIteration = 997
#
# Training on fold [1/5]
#
# bestTest = 0.03189122573
# bestIteration = 995
#
# Training on fold [2/5]
#
# bestTest = 0.03122991812
# bestIteration = 349
#
# Training on fold [3/5]
#
# bestTest = 0.03457315186
# bestIteration = 471
#
# Training on fold [4/5]
#
# bestTest = 0.03328455877
# bestIteration = 868

# %% [markdown]
# ## Forecast share model

# %%
from catboost import Pool, CatBoostRegressor

# %%
fcst = make_prediction(df, pd.to_datetime('2024-02-29'), 'S_share', 4, CatBoostRegressor())

# %%
pd.Series([1,1,1,1]).rolling(window = 4, min_periods = 1).max()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# dtype: float64

# %%
fcst_res = fcst.groupby('objectid').apply(lambda df: df.sort_values('report_date').assign(S_share = 
                        np.minimum(1, df.sort_values('report_date')['S_share'].rolling(window = df.shape[0], min_periods=1).max())
                                                             )).reset_index(drop = True)
fcst_res.to_parquet('s_share_pred.parquet')

# %%
fcst_res.count()
# Out:
# objectid         1321
# forecast_step    1321
# report_date      1321
# S_share          1321
# S                1321
# close_date       1321
# escrow_volume     332
# dtype: int64

# %%
df[df['objectid'] == 37509].sort_values('report_date')
# Out:
#        objectid report_date  escrow_inflow  S_inflow  S_object  \
# 16066   37509.0  2016-12-31            NaN       NaN  81099.02
# 16067   37509.0  2017-01-31            NaN       NaN  81099.02
# 16068   37509.0  2017-02-28            NaN       NaN  81099.02
# 16069   37509.0  2017-03-31            NaN       NaN  81099.02
# 16070   37509.0  2017-04-30            NaN       NaN  81099.02
# ...         ...         ...            ...       ...       ...
# 538     37509.0  2024-11-30            NaN       NaN  81099.02
# 539     37509.0  2024-12-31            NaN       NaN  81099.02
# 540     37509.0  2025-01-31            NaN       NaN  81099.02
# 541     37509.0  2025-02-28            NaN       NaN  81099.02
# 542     37509.0  2025-03-31            NaN       NaN  81099.02
#
#       object_open_date object_close_date escrow_plan_close escrow_fact_close  \
# 16066       2014-12-30        2025-03-31               NaT               NaT
# ...

# %%
px.line(fcst_res[fcst_res['objectid'] == 37509].set_index('report_date')['S_share'].sort_index())

# %% [markdown]
# ## Model analysis

# %%
from sklearn.metrics import mean_absolute_error as mae, mean_absolute_percentage_error as mape, r2_score as r2, mean_squared_error as mse

# %%
len(list(CustomSplit(df_train)))
# Out:
# 5

# %%
step = 1
res_list = []
for model, idxs in zip(iter_scores[1], CustomSplit(df_train)):
        for i, train_flg in enumerate([True, False]):
            res = pd.DataFrame({'report_date': df_train.iloc[idxs[i]]['report_date'].values,
                          'object': df_train.iloc[idxs[i]]['objectid'].values,
                          'fact': df_train.iloc[idxs[i]]['S_volume'].values, 
                          'fact_share': df_train.iloc[idxs[i]]['S_share'].values,
                          'pred_share': np.maximum(np.minimum(model.predict(X_train.iloc[idxs[i], :]), 1), 0),
                          'pred': X_train.iloc[idxs[i]]['S'].values * np.maximum(np.minimum(model.predict(X_train.iloc[idxs[i], :]), 1), 0),
                          'step': step,
                          'train_flg': train_flg})
            res_list.append(res)
        step += 1
res = pd.concat(res_list)

# %%
res
# Out:
#     report_date   object      fact  fact_share  pred_share          pred  \
# 0    2016-03-31  31459.0      0.00    0.000000    0.000000      0.000000
# 1    2016-04-30  31459.0      0.00    0.000000    0.000000      0.000000
# 2    2016-05-31  31459.0      0.00    0.000000    0.000000      0.000000
# 3    2016-06-30  31459.0      0.00    0.000000    0.000000      0.000000
# 4    2016-07-31  31459.0      0.00    0.000000    0.000000      0.000000
# ..          ...      ...       ...         ...         ...           ...
# 733  2023-12-31  18202.0  34260.10    1.000000    0.988698  33872.877554
# 734  2023-12-31  44030.0  18665.49    0.728839    0.692388  17731.983068
# 735  2023-12-31  43311.0   5005.75    0.947520    0.952357   5031.301099
# 736  2023-12-31  42672.0  15345.46    0.993527    0.847808  13094.770651
# 737  2023-12-31  44633.0  15593.02    0.963736    0.933598  15105.398331
#
#      step  train_flg
# 0       1       True
# 1       1       True
# 2       1       True
# ...

# %%
for obj, df_ in list(res[res['train_flg'] == False].groupby('object'))[:10]:
    #display(df_.iloc[:40, :])
    
    px.line(df_.sort_values('report_date'), x = 'report_date', y = ['fact_share', 'pred_share']).show()

# %%
for flg in [False, True]:
    display(res[res['train_flg'] == flg].groupby('step').apply(lambda df: pd.Series({'mae': mae(df['fact_share'], df['pred_share']), 
                                                                                     'r2': r2(df['fact_share'], df['pred_share']),
                                                                                    'rmse': mse(df['fact_share'], df['pred_share'])**(1/2),
                                                                                    'mape': mape(df['fact_share'], df['pred_share'])})).append(
        pd.Series({'mae': mae(res[res['train_flg'] == flg]['fact_share'], res[res['train_flg'] == flg]['pred_share']),
                  'r2': r2(res[res['train_flg'] == flg]['fact_share'], res[res['train_flg'] == flg]['pred_share']),
                  'rmse': mse(res[res['train_flg'] == flg]['fact_share'], res[res['train_flg'] == flg]['pred_share'])**(1/2),
                  'mape': mape(res[res['train_flg'] == flg]['fact_share'], res[res['train_flg'] == flg]['pred_share'])}, name = 'all')))
# Out:
#            mae        r2      rmse          mape
# step
# 1     0.037915  0.962995  0.070378  2.195544e+12
# 2     0.031603  0.979498  0.051633  3.943460e+12
# 3     0.032673  0.975714  0.055328  1.045438e+13
# 4     0.036846  0.972035  0.058744  5.886104e+12
# 5     0.032990  0.977557  0.053163  9.874139e+10
# all   0.034554  0.973083  0.059109  4.594204e+12
#            mae        r2      rmse          mape
# step
# 1     0.034969  0.947123  0.086083  2.094856e+12
# 2     0.034399  0.952376  0.083169  2.188224e+12
# 3     0.033880  0.955644  0.081204  2.274363e+12
# 4     0.033882  0.956524  0.081220  1.786838e+12
# 5     0.034126  0.957336  0.081152  1.996514e+12
# all   0.034225  0.954361  0.082447  2.061616e+12

# %%
res.merge(df.sort_values('report_date').groupby('objectid').apply(lambda df: 
                                            df.assign(S_share_shift = df['S_share'].shift().fillna(0),
                                            escrow_volume_shift = df['escrow_volume'].shift().fillna(0)))\
        [['report_date', 'objectid', 'escrow_volume', 'mean_price_per_metr', 'S_share', 'S', 'S_inflow', 'S_share_shift', 'escrow_volume_shift']].rename(columns = {'objectid': 'object'}), 
              on = ['report_date', 'object']).fillna(0).to_parquet('s_share_res.parquet')

# %%
res[res['train_flg'] == False].groupby(['step', 'report_date'], as_index = False).apply(lambda df: 
                                    pd.Series({'mape': mape([df['fact'].sum()], [df['pred'].sum()]), 'r2': r2()}))
# Out:
#     step report_date      mape
# 0      1  2022-10-31  0.018942
# 1      1  2022-11-30  0.041664
# 2      1  2022-12-31  0.007104
# 3      2  2023-01-31  0.015713
# 4      2  2023-02-28  0.007594
# 5      2  2023-03-31  0.021127
# 6      3  2023-04-30  0.013285
# 7      3  2023-05-31  0.009867
# 8      3  2023-06-30  0.023678
# 9      4  2023-07-31  0.039773
# 10     4  2023-08-31  0.029800
# 11     4  2023-09-30  0.008669
# 12     5  2023-10-31  0.008713
# 13     5  2023-11-30  0.015281
# 14     5  2023-12-31  0.017555

# %%
res[res['train_flg'] == False].groupby(['step', 'report_date']).apply(lambda df: 
                                pd.Series({'mape': mape([df['fact'].sum()], [df['pred'].sum()]),
                                          'mae': mae([df['fact'].sum()], [df['pred'].sum()])})).mean().rename('all')
# Out:
# mape        0.018584
# mae     85682.997077
# Name: all, dtype: float64

# %%
res[res['train_flg'] == False].groupby(['step', 'report_date'], as_index = False).apply(lambda df: 
                                pd.Series({'mape': mape([df['fact'].sum()], [df['pred'].sum()]),
                                           'mae': mae([df['fact'].sum()], [df['pred'].sum()])
                                          })).groupby('step').agg({'mape': 'mean', 'mae': 'mean'}).append(
    res[res['train_flg'] == False].groupby(['step', 'report_date']).apply(lambda df: 
                                pd.Series({'mape': mape([df['fact'].sum()], [df['pred'].sum()]),
                                          'mae': mae([df['fact'].sum()], [df['pred'].sum()])})).mean().rename('all')
    
).round(4)
# Out:
#         mape          mae
# step
# 1     0.0226  112433.1599
# 2     0.0148   69749.5402
# 3     0.0156   73565.3140
# 4     0.0261  115970.5442
# 5     0.0138   56696.4271
# all   0.0186   85682.9971

# %%
import plotly.io as pio
pio.templates.default = 'plotly_white'

fig = px.line(res[res['train_flg'] == False].groupby('report_date').agg({'step': 'first', 'fact': 'sum', 'pred': 'sum'}).rename(columns = {'pred': 'Предсказанные значения', 'fact': 'Фактические значения'}),
              title = 'Бэктест модели для суммарного ряда проданных площадей', line_group = 'step', markers = True, height = 500)
for dt in res[res['train_flg'] == False].groupby('step').agg({'report_date': 'max'})['report_date'].values[:-1]:
    fig.add_vline(x = pd.to_datetime(dt), line_dash = 'dash')
#fig.update_yaxes(visible = False)
fig.update_layout(font = dict(size = 15), xaxis_title = 'Дата', yaxis_title = 'Проданные квадратные метры', legend_title = '')

# %%
for model in iter_scores[1]:
    px.bar(x = model.feature_names_, y = model.get_feature_importance()).show()

# %%
df_train
# Out:
#       report_date  objectid         S  december_nums  S_share_shift_3  \
# 3636   2016-03-31   31459.0  39693.55              0         0.000000
# 3637   2016-04-30   31459.0  39693.55              0         0.000000
# 3638   2016-05-31   31459.0  39693.55              0         0.000000
# 3639   2016-06-30   31459.0  39693.55              0         0.000000
# 3640   2016-07-31   31459.0  39693.55              0         0.000000
# ...           ...       ...       ...            ...              ...
# 1361   2023-12-31   18202.0  34260.10              6         1.000000
# 22567  2023-12-31   44030.0  25609.91              3         0.551592
# 22382  2023-12-31   43311.0   5283.00              3         0.884696
# 14819  2023-12-31   42672.0  15445.44              3         0.670771
# 16984  2023-12-31   44633.0  16179.76              4         0.834512
#
#        key_rate  key_rate_diff  key_rate-key_rate_mean_3  \
# 3636       11.0            0.0                  0.000000
# ...
